# %% [markdown]
# Group Member: Roja Kafle
# Final Project(Saftey): Blood lead level

# %% [markdown]
# Introduction: The submetric I chose was the the level of lead found in blood work. I chose this because I feel like health saftey is often overlooked when people look at how safe a neighnorhood is. In addition, lead poisning is a major concern in our area.The dataset shows information about the percentage of school children with blood lead levels in school districts across allegheny county

# %%
# This code set sorts the blood lead level from highest to lowest by school district chronologically between the years 2015-2020



import pandas as pd


order = pd.read_csv('Bloodlevel.csv')


order_2015 = order[['SchoolDistrict', 'percentEBLL2015']]


sorted_order_2015 = order_2015.sort_values(by='percentEBLL2015', ascending=False)


print(sorted_order_2015)
print()

order_2016=order[['SchoolDistrict','percentEBLL2016']]
sorted_order_2016=order_2016.sort_values(by='percentEBLL2016', ascending=False)

print(sorted_order_2016)
print()

order_2017=order[['SchoolDistrict','percentEBLL2017']]
sorted_order_2017=order_2017.sort_values(by='percentEBLL2017', ascending=False)
print(sorted_order_2017)
print()


order_2018=order[['SchoolDistrict','percentEBLL2018']]
sorted_order_2018=order_2018.sort_values(by='percentEBLL2018', ascending=False)
print(sorted_order_2018)

print()


order_2019=order[['SchoolDistrict','percentEBLL2019']]
sorted_order_2019=order_2019.sort_values(by='percentEBLL2019', ascending=False)
print(sorted_order_2019)
print()


order_2020=order[['SchoolDistrict','percent2020']]
sorted_order_2020=order_2020.sort_values(by='percent2020', ascending=False)
print(sorted_order_2020)
print()
# Out:
#             SchoolDistrict  percentEBLL2015
# 26               Northgate             9.66
# 20         McKeesport Area             6.75
# 43             Wilkinsburg             6.20
# 7       City of Pittsburgh             5.55
# 11           Duquesne City             3.88
# 12          East Allegheny             3.54
# 44          Woodland Hills             3.45
# 31           Quaker Valley             2.83
# 8            Clairton City             2.73
# 32               Riverview             2.44
# 22               Moon Area             2.31
# 37            Steel Valley             2.19
# 33             Shaler Area             2.11
# 38                 Sto-Rox             2.05
# 9                  Cornell             1.67
# 4        Brentwood Borough             1.60
# 16                 Gateway             1.59
# 19           Keystone Oaks             1.54
# 6         Chartiers Valley             1.53
# 18               Highlands             1.15
# 15         Fox Chapel Area             1.09
# 42       West Mifflin Area             0.97
# 2        Baldwin-Whitehall             0.91
# 27              Penn Hills             0.89
# 1                Avonworth             0.72
# 5                Carlynton             0.66
# 21                 Montour             0.65
# 34         South Allegheny             0.55
# 23             Mt. Lebanon             0.43
# 41    West Jefferson Hills             0.39
# 25             North Hills             0.27
# 40          West Allegheny             0.00
# 39    Upper St. Clair Area             0.00
# 10              Deer Lakes             0.00
# 29           Pine-Richland             0.00
# 36              South Park             0.00
# 35  South Fayette Township             0.00
# 3              Bethel Park             0.00
# 30            Plum Borough             0.00
# 24         North Allegheny             0.00
# 17        Hampton Township             0.00
# 13       Elizabeth Forward             0.00
# 0         Allegheny Valley             0.00
# 14             Fort Cherry              NaN
# 28           Penn-Trafford              NaN
#
#             SchoolDistrict  percentEBLL2016
# 11           Duquesne City             7.55
# 34         South Allegheny             5.92
# 43             Wilkinsburg             5.73
# 20         McKeesport Area             5.62
# 7       City of Pittsburgh             5.53
# 26               Northgate             5.19
# 44          Woodland Hills             4.81
# 12          East Allegheny             4.64
# 38                 Sto-Rox             4.52
# 37            Steel Valley             3.33
# 16                 Gateway             3.19
# 22               Moon Area             3.17
# 5                Carlynton             3.05
# 33             Shaler Area             3.02
# 9                  Cornell             2.90
# 27              Penn Hills             2.39
# 6         Chartiers Valley             2.15
# 31           Quaker Valley             1.98
# 18               Highlands             1.67
# 42       West Mifflin Area             1.48
# 4        Brentwood Borough             1.35
# 21                 Montour             1.33
# 32               Riverview             1.11
# 25             North Hills             0.78
# 1                Avonworth             0.75
# 23             Mt. Lebanon             0.69
# 8            Clairton City             0.63
# 2        Baldwin-Whitehall             0.59
# 13       Elizabeth Forward             0.54
# 15         Fox Chapel Area             0.49
# 39    Upper St. Clair Area             0.00
# 10              Deer Lakes             0.00
# 41    West Jefferson Hills             0.00
# 40          West Allegheny             0.00
# 3              Bethel Park             0.00
# 29           Pine-Richland             0.00
# 36              South Park             0.00
# 35  South Fayette Township             0.00
# 30            Plum Borough             0.00
# 24         North Allegheny             0.00
# 19           Keystone Oaks             0.00
# 17        Hampton Township             0.00
# 0         Allegheny Valley             0.00
# 14             Fort Cherry              NaN
# 28           Penn-Trafford              NaN
#
#             SchoolDistrict  percentEBLL2017
# 5                Carlynton             8.06
# 43             Wilkinsburg             6.64
# 11           Duquesne City             6.62
# 26               Northgate             6.22
# 20         McKeesport Area             5.40
# 34         South Allegheny             5.26
# 7       City of Pittsburgh             4.76
# 37            Steel Valley             3.95
# 12          East Allegheny             3.52
# 4        Brentwood Borough             3.45
# 44          Woodland Hills             3.43
# 18               Highlands             2.46
# 13       Elizabeth Forward             2.29
# 21                 Montour             2.05
# 38                 Sto-Rox             1.83
# 33             Shaler Area             1.81
# 42       West Mifflin Area             1.75
# 35  South Fayette Township             1.64
# 25             North Hills             1.44
# 19           Keystone Oaks             1.42
# 6         Chartiers Valley             1.41
# 2        Baldwin-Whitehall             1.40
# 22               Moon Area             1.33
# 8            Clairton City             1.18
# 0         Allegheny Valley             0.92
# 15         Fox Chapel Area             0.83
# 32               Riverview             0.78
# 10              Deer Lakes             0.73
# 31           Quaker Valley             0.72
# 40          West Allegheny             0.68
# 3              Bethel Park             0.61
# 27              Penn Hills             0.60
# 36              South Park             0.60
# 39    Upper St. Clair Area             0.56
# 1                Avonworth             0.55
# 23             Mt. Lebanon             0.30
# 16                 Gateway             0.25
# 24         North Allegheny             0.19
# 29           Pine-Richland             0.00
# 9                  Cornell             0.00
# 17        Hampton Township             0.00
# 41    West Jefferson Hills             0.00
# 30            Plum Borough             0.00
# 14             Fort Cherry              NaN
# 28           Penn-Trafford              NaN
#
#             SchoolDistrict  percentEBLL2018
# 43             Wilkinsburg             6.77
# 20         McKeesport Area             6.45
# 26               Northgate             5.77
# 5                Carlynton             5.49
# 7       City of Pittsburgh             4.00
# 38                 Sto-Rox             3.27
# 44          Woodland Hills             3.04
# 4        Brentwood Borough             2.68
# 6         Chartiers Valley             2.64
# 18               Highlands             2.40
# 32               Riverview             2.30
# 31           Quaker Valley             2.21
# 11           Duquesne City             2.16
# 33             Shaler Area             2.16
# 9                  Cornell             1.96
# 16                 Gateway             1.70
# 12          East Allegheny             1.65
# 42       West Mifflin Area             1.58
# 2        Baldwin-Whitehall             1.42
# 37            Steel Valley             1.39
# 25             North Hills             1.37
# 8            Clairton City             1.14
# 35  South Fayette Township             1.04
# 21                 Montour             1.03
# 34         South Allegheny             1.01
# 1                Avonworth             0.89
# 15         Fox Chapel Area             0.82
# 13       Elizabeth Forward             0.79
# 0         Allegheny Valley             0.68
# 39    Upper St. Clair Area             0.67
# 40          West Allegheny             0.65
# 27              Penn Hills             0.49
# 24         North Allegheny             0.36
# 19           Keystone Oaks             0.34
# 23             Mt. Lebanon             0.33
# 41    West Jefferson Hills             0.22
# 22               Moon Area             0.22
# 3              Bethel Park             0.18
# 30            Plum Borough             0.00
# 29           Pine-Richland             0.00
# 36              South Park             0.00
# 17        Hampton Township             0.00
# 10              Deer Lakes             0.00
# 14             Fort Cherry              NaN
# 28           Penn-Trafford              NaN
#
#             SchoolDistrict  percentEBLL2019
# 43             Wilkinsburg             6.71
# 20         McKeesport Area             6.30
# 5                Carlynton             4.05
# 7       City of Pittsburgh             3.84
# 38                 Sto-Rox             3.67
# 26               Northgate             3.05
# 11           Duquesne City             2.89
# 9                  Cornell             2.73
# 37            Steel Valley             2.66
# 44          Woodland Hills             2.62
# 4        Brentwood Borough             2.54
# 8            Clairton City             2.40
# 32               Riverview             2.05
# 1                Avonworth             2.00
# 18               Highlands             1.86
# 6         Chartiers Valley             1.78
# 25             North Hills             1.54
# 42       West Mifflin Area             1.43
# 16                 Gateway             1.08
# 19           Keystone Oaks             1.05
# 34         South Allegheny             0.99
# 3              Bethel Park             0.89
# 12          East Allegheny             0.85
# 13       Elizabeth Forward             0.74
# 21                 Montour             0.68
# 15         Fox Chapel Area             0.64
# 10              Deer Lakes             0.49
# 2        Baldwin-Whitehall             0.49
# 36              South Park             0.43
# 27              Penn Hills             0.41
# 22               Moon Area             0.35
# 24         North Allegheny             0.27
# 40          West Allegheny             0.26
# 33             Shaler Area             0.18
# 23             Mt. Lebanon             0.15
# 31           Quaker Valley             0.00
# 35  South Fayette Township             0.00
# 30            Plum Borough             0.00
# 29           Pine-Richland             0.00
# 39    Upper St. Clair Area             0.00
# 41    West Jefferson Hills             0.00
# 17        Hampton Township             0.00
# 0         Allegheny Valley             0.00
# 14             Fort Cherry              NaN
# 28           Penn-Trafford              NaN
#
#             SchoolDistrict  percent2020
# 20         McKeesport Area         6.69
# 8            Clairton City         6.02
# 43             Wilkinsburg         5.67
# 11           Duquesne City         5.26
# 26               Northgate         4.82
# 7       City of Pittsburgh         2.95
# 4        Brentwood Borough         2.31
# 32               Riverview         2.06
# 18               Highlands         1.99
# 44          Woodland Hills         1.86
# 9                  Cornell         1.85
# 37            Steel Valley         1.58
# 34         South Allegheny         1.54
# 12          East Allegheny         1.49
# 16                 Gateway         1.34
# 0         Allegheny Valley         1.30
# 38                 Sto-Rox         1.27
# 6         Chartiers Valley         1.19
# 35  South Fayette Township         1.10
# 31           Quaker Valley         0.81
# 10              Deer Lakes         0.79
# 22               Moon Area         0.70
# 17        Hampton Township         0.67
# 5                Carlynton         0.60
# 1                Avonworth         0.56
# 36              South Park         0.55
# 27              Penn Hills         0.50
# 25             North Hills         0.43
# 19           Keystone Oaks         0.35
# 42       West Mifflin Area         0.34
# 33             Shaler Area         0.29
# 23             Mt. Lebanon         0.20
# 2        Baldwin-Whitehall         0.19
# 24         North Allegheny         0.00
# 21                 Montour         0.00
# 15         Fox Chapel Area         0.00
# 3              Bethel Park         0.00
# 30            Plum Borough         0.00
# 39    Upper St. Clair Area         0.00
# 40          West Allegheny         0.00
# 41    West Jefferson Hills         0.00
# 29           Pine-Richland         0.00
# 13       Elizabeth Forward         0.00
# 14             Fort Cherry          NaN
# 28           Penn-Trafford          NaN

# %%
#graph

import pandas as pd
import matplotlib.pyplot as plt
graph = pd.read_csv('Bloodlevel.csv')
graph_sorted = graph.sort_values(by='percentEBLL2019')
graph_sorted.plot(x='SchoolDistrict', y='percentEBLL2019', kind='barh')
plt.xlabel('Percent of children with elevated blood lead levels in 2019')
plt.ylabel('School District')
plt.title('Percent of Children with Elevated Blood Lead Levels by School District in 2019')
plt.rcParams["figure.figsize"] = (20, 8)
plt.show()

# %%
#randomly choses 15 school from the datset and shows the schools with the highest blood lead level
# are able to change the year hence changing the graph


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


high = pd.read_csv('Bloodlevel.csv')
schools = np.random.choice(high['SchoolDistrict'].unique(), size=15, replace=False)
high_filtered = high[high['SchoolDistrict'].isin(schools)]
high_sorted = high_filtered.sort_values(by=['percentEBLL2015'], ascending=False)
plt.figure(figsize=(12, 6))
plt.bar(high_sorted['SchoolDistrict'], high_sorted['percentEBLL2016'])
plt.xticks(rotation=45, ha='right')
plt.xlabel('SchoolDistrict')
plt.ylabel('Blood Lead Level')
plt.title('Blood Lead Levels by School')
plt.show()

# %%
import pandas as pd

mean_level = pd.read_csv('Bloodlevel.csv')
district_means = mean_level.groupby('SchoolDistrict')['percentEBLL2018'].mean()
highest_district = district_means.idxmax()
print(f"The school district with the highest mean blood lead level is {highest_district}")
# Out:
# The school district with the highest mean blood lead level is Wilkinsburg

# %%
import pandas as pd

low_level = pd.read_csv("Bloodlevel.csv")
district_means = low_level.groupby("SchoolDistrict")['percentEBLL2015'].mean()
lowest_mean_district = district_means.idxmax()
print(f"School district with the lowest mean blood lead level is {lowest_mean_district}")
# Out:
# School district with the lowest mean blood lead level is Northgate

# %%
# randomly choses 20 schools from the data frame and sorts them from the school district with the lowest blood lead level to the highest

import pandas as pd
import random
import matplotlib.pyplot as plt


ran = pd.read_csv('Bloodlevel.csv')
schools = random.sample(list(ran['SchoolDistrict'].unique()), 20)
ran = ran[ran['SchoolDistrict'].isin(schools)]
ran = ran.sort_values(by='percentEBLL2015')
plt.bar(ran['SchoolDistrict'], ran['percentEBLL2015'])
plt.xticks(rotation=90)
plt.xlabel('School')
plt.ylabel('Blood Level')
plt.title('Blood Levels for 20 Randomly Chosen Schools')
plt.show()

# %% [markdown]
# Chosing which neighborhood area is safest in terms of blood lead level found between 2015-2020

# %%
import pandas as pd
safe = pd.read_csv('Bloodlevel.csv')
indices = ['percentEBLL2015','percentEBLL2016','percentEBLL2017','percentEBLL2018','percentEBLL2019','percent2020']
avg_lead_levels = safe.groupby('SchoolDistrict')[indices].mean()
safest_school = avg_lead_levels.mean(axis=1).idxmin()
print(f"The safest school is {safest_school}")
# Out:
# The safest school is Pine-Richland

# %% [markdown]
# Conclusion:
#
# Based on my submetric the safest Neighborhood should be Pine-Richland with the lowest blood lead level tested throughout 2015-2020
